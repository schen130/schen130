# %%
import sqlite3 as sql
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
#all_frames returns all the dataframe tables that can be created by passing in the html
df = pd.read_csv('vgsales.csv')

# %%
len(df)
# Out:
# 16598

# %%
df.head()
# Out:
#    Rank                      Name Platform    Year         Genre Publisher  \
# 0     1                Wii Sports      Wii  2006.0        Sports  Nintendo
# 1     2         Super Mario Bros.      NES  1985.0      Platform  Nintendo
# 2     3            Mario Kart Wii      Wii  2008.0        Racing  Nintendo
# 3     4         Wii Sports Resort      Wii  2009.0        Sports  Nintendo
# 4     5  Pokemon Red/Pokemon Blue       GB  1996.0  Role-Playing  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 0     41.49     29.02      3.77         8.46         82.74
# 1     29.08      3.58      6.81         0.77         40.24
# 2     15.85     12.88      3.79         3.31         35.82
# 3     15.75     11.01      3.28         2.96         33.00
# 4     11.27      8.89     10.22         1.00         31.37

# %%
df2 = pd.read_csv('video_game.csv')

# %%
len(df2)
# Out:
# 16719

# %%
df2.iloc[50:100]
# Out:
#     Unnamed: 0                                    Name Platform  \
# 50          51      Super Mario Land 2: 6 Golden Coins       GB
# 51          52                     Grand Theft Auto IV     X360
# 52          53                            Gran Turismo       PS
# 53          54                     Super Mario 3D Land      3DS
# 54          55                          Gran Turismo 5      PS3
# 55          56          Call of Duty: Modern Warfare 2      PS3
# 56          57                   Super Mario All-Stars     SNES
# 57          58                     Grand Theft Auto IV      PS3
# 58          59       Pokemon FireRed/Pokemon LeafGreen      GBA
# 59          60                          Super Mario 64       DS
# 60          61                    Call of Duty: Ghosts     X360
# 61          62                            Just Dance 3      Wii
# 62          63                 New Super Mario Bros. 2      3DS
# 63          64                           Mario Kart 64      N64
# 64          65                             Halo: Reach     X360
# 65          66                       Final Fantasy VII       PS
# 66          67                                  Halo 4     X360
# 67          68                          Gran Turismo 2       PS
# 68          69                            Just Dance 2      Wii
# 69          70                    Call of Duty: Ghosts      PS3
# 70          71          Call of Duty 4: Modern Warfare     X360
# 71          72                     Donkey Kong Country     SNES
# 72          73                               Minecraft     X360
# 73          74               Animal Crossing: New Leaf      3DS
# 74          75                          Mario Party DS       DS
# 75          76             The Elder Scrolls V: Skyrim     X360
# 76          77                        Super Mario Kart     SNES
# 77          78                                 FIFA 16      PS4
# 78          79                                  Halo 2       XB
# 79          80                               Wii Party      Wii
# 80          81                           Mario Party 8      Wii
# 81          82                          FIFA Soccer 13      PS3
# 82          83                           GoldenEye 007      N64
# 83          84         Pokemon Black 2/Pokemon White 2       DS
# 84          85                         Final Fantasy X      PS2
# 85          86                              The Sims 3       PC
# 86          87      Mario & Sonic at the Olympic Games      Wii
# 87          88            Star Wars Battlefront (2015)      PS4
# 88          89                      Final Fantasy VIII       PS
# 89          90                                 Pac-Man     2600
# 90          91                Pokémon Platinum Version       DS
# 91          92  Grand Theft Auto: Liberty City Stories      PSP
# 92          93          Call of Duty: Advanced Warfare      PS4
# 93          94    The Legend of Zelda: Ocarina of Time      N64
# 94          95                                 FIFA 17      PS4
# 95          96  Crash Bandicoot 2: Cortex Strikes Back       PS
# 96          97     Super Smash Bros. for Wii U and 3DS      3DS
# 97          98                    Super Mario Galaxy 2      Wii
# 98          99                     Super Mario Bros. 2      NES
# 99         100               Call of Duty: Black Ops 3     XOne
#
#     Year_of_Release         Genre                    Publisher  NA_players  \
# 50           1992.0     Adventure                     Nintendo        6.16
# 51           2008.0        Action         Take-Two Interactive        6.76
# 52           1997.0        Racing  Sony Computer Entertainment        4.02
# 53           2011.0      Platform                     Nintendo        4.89
# 54           2010.0        Racing  Sony Computer Entertainment        2.96
# 55           2009.0       Shooter                   Activision        4.99
# 56           1993.0      Platform                     Nintendo        5.99
# 57           2008.0        Action         Take-Two Interactive        4.76
# 58           2004.0  Role-Playing                     Nintendo        4.34
# 59           2004.0      Platform                     Nintendo        5.01
# 60           2013.0       Shooter                   Activision        6.73
# 61           2011.0          Misc                      Ubisoft        5.95
# 62           2012.0      Platform                     Nintendo        3.66
# 63           1996.0        Racing                     Nintendo        5.55
# 64           2010.0       Shooter       Microsoft Game Studios        7.04
# 65           1997.0  Role-Playing  Sony Computer Entertainment        3.01
# 66           2012.0       Shooter       Microsoft Game Studios        6.65
# 67           1999.0        Racing  Sony Computer Entertainment        3.88
# 68           2010.0          Misc                      Ubisoft        5.80
# 69           2013.0       Shooter                   Activision        4.10
# 70           2007.0       Shooter                   Activision        5.93
# 71           1994.0      Platform                     Nintendo        4.36
# 72           2013.0          Misc       Microsoft Game Studios        5.70
# 73           2012.0    Simulation                     Nintendo        2.03
# 74           2007.0          Misc                     Nintendo        4.40
# 75           2011.0  Role-Playing           Bethesda Softworks        5.05
# 76           1992.0        Racing                     Nintendo        3.54
# 77           2015.0        Sports              Electronic Arts        1.12
# 78           2004.0       Shooter       Microsoft Game Studios        6.82
# 79           2010.0          Misc                     Nintendo        1.75
# 80           2007.0          Misc                     Nintendo        3.74
# 81           2012.0        Action              Electronic Arts        1.06
# 82           1997.0       Shooter                     Nintendo        5.80
# 83           2012.0  Role-Playing                     Nintendo        2.79
# 84           2001.0  Role-Playing  Sony Computer Entertainment        2.91
# 85           2009.0    Simulation              Electronic Arts        0.99
# 86           2007.0        Sports                         Sega        2.57
# 87           2015.0       Shooter              Electronic Arts        2.99
# 88           1999.0  Role-Playing                   SquareSoft        2.28
# 89           1982.0        Puzzle                        Atari        7.28
# 90           2008.0  Role-Playing                     Nintendo        2.76
# 91           2005.0        Action         Take-Two Interactive        2.90
# 92           2014.0       Shooter                   Activision        2.81
# 93           1998.0        Action                     Nintendo        4.10
# 94           2016.0        Sports              Electronic Arts        0.66
# 95           1997.0      Platform  Sony Computer Entertainment        3.78
# 96           2014.0      Fighting                     Nintendo        3.27
# 97           2010.0      Platform                     Nintendo        3.56
# 98           1988.0      Platform                     Nintendo        5.39
# 99           2015.0       Shooter                   Activision        4.59
#
#     EU_players  JP_players  Other_players  Global_players  Critic_Score  \
# 50        2.04        2.69           0.29           11.18           NaN
# 51        3.07        0.14           1.03           11.01          98.0
# 52        3.87        2.54           0.52           10.95          96.0
# 53        3.00        2.14           0.78           10.81          90.0
# 54        4.82        0.81           2.11           10.70          84.0
# 55        3.64        0.38           1.60           10.60          94.0
# 56        2.15        2.12           0.29           10.55           NaN
# 57        3.69        0.44           1.61           10.50          98.0
# 58        2.65        3.15           0.35           10.49           NaN
# 59        3.07        1.25           0.97           10.30           NaN
# 60        2.56        0.04           0.91           10.25          73.0
# 61        3.11        0.00           1.06           10.12          74.0
# 62        3.14        2.47           0.63            9.90          78.0
# 63        1.94        2.23           0.15            9.87           NaN
# 64        1.95        0.08           0.79            9.86          91.0
# 65        2.47        3.28           0.96            9.72          92.0
# 66        2.28        0.04           0.74            9.71          87.0
# 67        3.42        1.69           0.50            9.49          93.0
# 68        2.85        0.01           0.78            9.44          74.0
# 69        3.63        0.38           1.25            9.36          71.0
# 70        2.36        0.13           0.90            9.31          94.0
# 71        1.71        3.00           0.23            9.30           NaN
# 72        2.65        0.02           0.81            9.18           NaN
# 73        2.36        4.39           0.39            9.16          88.0
# 74        1.85        1.98           0.68            8.91          72.0
# 75        2.79        0.10           0.85            8.79          96.0
# 76        1.24        3.81           0.18            8.76           NaN
# 77        6.12        0.06           1.28            8.57          82.0
# 78        1.53        0.05           0.08            8.49          95.0
# 79        3.47        2.49           0.67            8.38          68.0
# 80        2.24        1.58           0.70            8.27          62.0
# 81        5.01        0.13           1.97            8.16          88.0
# 82        2.01        0.13           0.15            8.09           NaN
# 83        1.72        3.14           0.41            8.07           NaN
# 84        2.07        2.73           0.33            8.05          92.0
# 85        6.42        0.00           0.60            8.01          86.0
# 86        3.86        0.66           0.91            7.99           NaN
# 87        3.49        0.22           1.28            7.98           NaN
# 88        1.72        3.63           0.23            7.86          90.0
# 89        0.45        0.00           0.08            7.81           NaN
# 90        1.72        2.69           0.54            7.72          83.0
# 91        2.81        0.24           1.73            7.69          88.0
# 92        3.48        0.14           1.23            7.66          83.0
# 93        1.89        1.45           0.16            7.60           NaN
# 94        5.75        0.08           1.11            7.59          85.0
# 95        2.17        1.31           0.31            7.58           NaN
# 96        1.37        2.43           0.48            7.55           NaN
# 97        2.35        0.98           0.62            7.51          97.0
# 98        1.18        0.70           0.19            7.46           NaN
# 99        2.11        0.01           0.68            7.39           NaN
#
#     Critic_Count User_Score  User_Count                Developer Rating
# 50           NaN        NaN         NaN                      NaN    NaN
# 51          86.0        7.9      2951.0           Rockstar North      M
# 52          16.0        8.7       138.0        Polyphony Digital      E
# 53          82.0        8.4       921.0                 Nintendo      E
# 54          82.0        7.5      1112.0        Polyphony Digital      E
# 55          67.0        6.3      2073.0            Infinity Ward      M
# 56           NaN        NaN         NaN                      NaN    NaN
# 57          64.0        7.5      2833.0           Rockstar North      M
# 58           NaN        NaN         NaN                      NaN    NaN
# 59           NaN        NaN         NaN                      NaN    NaN
# 60          29.0        2.6      2117.0            Infinity Ward      M
# 61          15.0        7.8        16.0                  Ubisoft   E10+
# 62          70.0        7.2       424.0                 Nintendo      E
# 63           NaN        NaN         NaN                      NaN    NaN
# 64          99.0        7.9      2045.0                   Bungie      M
# 65          20.0        9.2      1282.0               SquareSoft      T
# 66          87.0          7      3260.0           343 Industries      M
# 67          23.0          9       135.0        Polyphony Digital      T
# 68          24.0        7.3        24.0                  Ubisoft   E10+
# 69          10.0        2.6      1047.0            Infinity Ward      M
# 70          70.0        8.4      1320.0            Infinity Ward      M
# 71           NaN        NaN         NaN                      NaN    NaN
# 72           NaN        NaN         NaN                      NaN    NaN
# 73          70.0        8.7       626.0                 Nintendo      E
# 74          27.0        7.8        85.0              Hudson Soft      E
# 75          89.0        8.4      3589.0    Bethesda Game Studios      M
# 76           NaN        NaN         NaN                      NaN    NaN
# 77          42.0        4.3       896.0                EA Sports      E
# 78          91.0        8.2      1218.0          Bungie Software      M
# 79          42.0        7.4        54.0                  Nd Cube      E
# 80          41.0        6.3       190.0                   Hudson      E
# 81          37.0        6.6       348.0          Electronic Arts      E
# 82           NaN        NaN         NaN                      NaN    NaN
# 83           NaN        NaN         NaN                      NaN    NaN
# 84          53.0        8.7      1056.0               SquareSoft      T
# 85          75.0        7.6       886.0          The Sims Studio      T
# 86           NaN        NaN         NaN                      NaN    NaN
# 87           NaN        NaN         NaN                      NaN    NaN
# 88          24.0        8.6       644.0               SquareSoft      T
# 89           NaN        NaN         NaN                      NaN    NaN
# 90          46.0        8.5       203.0               Game Freak      E
# 91          65.0        7.6       451.0           Rockstar Leeds      M
# 92          39.0        5.7      1443.0       Sledgehammer Games      M
# 93           NaN        NaN         NaN                      NaN    NaN
# 94          41.0          5       398.0  EA Sports, EA Vancouver      E
# 95           NaN        NaN         NaN                      NaN    NaN
# 96           NaN        NaN         NaN                      NaN    NaN
# 97          87.0        9.1      1854.0       Nintendo EAD Tokyo      E
# 98           NaN        NaN         NaN                      NaN    NaN
# 99           NaN        NaN         NaN                      NaN    NaN

# %%
df3 = df.join(df2, on = 'Name', how = 'inner')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-12-e1218ede53b3> in <module>
# ----> 1 df3 = df.join(df2, on = 'Name', how = 'inner')
#
# /opt/conda/lib/python3.8/site-packages/pandas/core/frame.py in join(self, other, on, how, lsuffix, rsuffix, sort)
#    7872         5  K5  A5  NaN
#    7873         """
# -> 7874         return self._join_compat(
#    7875             other, on=on, how=how, lsuffix=lsuffix, rsuffix=rsuffix, sort=sort
#    7876         )
#
# /opt/conda/lib/python3.8/site-packages/pandas/core/frame.py in _join_compat(self, other, on, how, lsuffix, rsuffix, sort)
#    7888
#    7889         if isinstance(other, DataFrame):
# -> 7890             return merge(
#    7891                 self,
#    7892                 other,
#
# /opt/conda/lib/python3.8/site-packages/pandas/core/reshape/merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#      72     validate=None,
#      73 ) -> "DataFrame":
# ---> 74     op = _MergeOperation(
#      75         left,
#      76         right,
#
# /opt/conda/lib/python3.8/site-packages/pandas/core/reshape/merge.py in __init__(self, left, right, how, on, left_on, right_on, axis, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     654         # validate the merge keys dtypes. We may need to coerce
#     655         # to avoid incompatible dtypes
# --> 656         self._maybe_coerce_merge_keys()
#     657
#     658         # If argument passed to validate,
#
# /opt/conda/lib/python3.8/site-packages/pandas/core/reshape/merge.py in _maybe_coerce_merge_keys(self)
#    1163                     inferred_right in string_types and inferred_left not in string_types
#    1164                 ):
# -> 1165                     raise ValueError(msg)
#    1166
#    1167             # datetimelikes must match exactly
#
# ValueError: You are trying to merge on object and int64 columns. If you wish to proceed you should use pd.concat

# %%
df3 = pd.concat([df, df2], axis = 1, join = 'inner')

# %%
df3.head()
# Out:
#    Rank                      Name Platform    Year         Genre Publisher  \
# 0     1                Wii Sports      Wii  2006.0        Sports  Nintendo
# 1     2         Super Mario Bros.      NES  1985.0      Platform  Nintendo
# 2     3            Mario Kart Wii      Wii  2008.0        Racing  Nintendo
# 3     4         Wii Sports Resort      Wii  2009.0        Sports  Nintendo
# 4     5  Pokemon Red/Pokemon Blue       GB  1996.0  Role-Playing  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  ...  EU_players  JP_players  \
# 0     41.49     29.02      3.77         8.46  ...       28.96        3.77
# 1     29.08      3.58      6.81         0.77  ...        3.58        6.81
# 2     15.85     12.88      3.79         3.31  ...       12.76        3.79
# 3     15.75     11.01      3.28         2.96  ...       10.93        3.28
# 4     11.27      8.89     10.22         1.00  ...        8.89       10.22
#
#   Other_players Global_players  Critic_Score Critic_Count User_Score  \
# 0          8.45          82.53          76.0         51.0          8
# 1          0.77          40.24           NaN          NaN        NaN
# 2          3.29          35.52          82.0         73.0        8.3
# 3          2.95          32.77          80.0         73.0          8
# 4          1.00          31.37           NaN          NaN        NaN
#
#    User_Count  Developer  Rating
# 0       322.0   Nintendo       E
# 1         NaN        NaN     NaN
# 2       709.0   Nintendo       E
# 3       192.0   Nintendo       E
# 4         NaN        NaN     NaN
#
# [5 rows x 28 columns]

# %%
print("xx")
