# %%
import sqlite3 as sql
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
#all_frames returns all the dataframe tables that can be created by passing in the html
df = pd.read_csv('vgsales.csv')

# %%
len(df)
# Out:
# 16598

# %%
df.head()
# Out:
#    Rank                      Name Platform    Year         Genre Publisher  \
# 0     1                Wii Sports      Wii  2006.0        Sports  Nintendo
# 1     2         Super Mario Bros.      NES  1985.0      Platform  Nintendo
# 2     3            Mario Kart Wii      Wii  2008.0        Racing  Nintendo
# 3     4         Wii Sports Resort      Wii  2009.0        Sports  Nintendo
# 4     5  Pokemon Red/Pokemon Blue       GB  1996.0  Role-Playing  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 0     41.49     29.02      3.77         8.46         82.74
# 1     29.08      3.58      6.81         0.77         40.24
# 2     15.85     12.88      3.79         3.31         35.82
# 3     15.75     11.01      3.28         2.96         33.00
# 4     11.27      8.89     10.22         1.00         31.37

# %%
df2 = pd.read_csv('video_game.csv')

# %%
len(df2)
# Out:
# 16719

# %%
df2.iloc[0:50]
# Out:
#     Unnamed: 0                                          Name Platform  \
# 0            1                                    Wii Sports      Wii
# 1            2                             Super Mario Bros.      NES
# 2            3                                Mario Kart Wii      Wii
# 3            4                             Wii Sports Resort      Wii
# 4            5                      Pokemon Red/Pokemon Blue       GB
# 5            6                                        Tetris       GB
# 6            7                         New Super Mario Bros.       DS
# 7            8                                      Wii Play      Wii
# 8            9                     New Super Mario Bros. Wii      Wii
# 9           10                                     Duck Hunt      NES
# 10          11                                    Nintendogs       DS
# 11          12                                 Mario Kart DS       DS
# ...

# %%
df2 = df2.rename(columns={"Year_of_Release": "Year"})

# %%
df3 = df.merge(df2, how='inner', on=['Name','Platform','Year','Genre','Publisher'])

# %%
print(len(df3))
# Out:
# 16524

# %%
df3 = df3.astype({'Platform': str})

# %%
df3.head()
# Out:
#    Rank                      Name Platform    Year         Genre Publisher  \
# 0     1                Wii Sports      Wii  2006.0        Sports  Nintendo
# 1     2         Super Mario Bros.      NES  1985.0      Platform  Nintendo
# 2     3            Mario Kart Wii      Wii  2008.0        Racing  Nintendo
# 3     4         Wii Sports Resort      Wii  2009.0        Sports  Nintendo
# 4     5  Pokemon Red/Pokemon Blue       GB  1996.0  Role-Playing  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  ...  EU_players  JP_players  \
# 0     41.49     29.02      3.77         8.46  ...       28.96        3.77
# 1     29.08      3.58      6.81         0.77  ...        3.58        6.81
# 2     15.85     12.88      3.79         3.31  ...       12.76        3.79
# 3     15.75     11.01      3.28         2.96  ...       10.93        3.28
# 4     11.27      8.89     10.22         1.00  ...        8.89       10.22
#
# ...

# %%
rslt_df = df3[df3['Name'] == 'Super Mario Bros.'] 
rslt_df
# Out:
#      Rank               Name Platform    Year     Genre Publisher  NA_Sales  \
# 1       2  Super Mario Bros.      NES  1985.0  Platform  Nintendo     29.08
# 200   201  Super Mario Bros.       GB  1999.0  Platform  Nintendo      3.40
#
#      EU_Sales  JP_Sales  Other_Sales  ...  EU_players  JP_players  \
# 1        3.58      6.81         0.77  ...        3.58        6.81
# 200      1.30      0.15         0.22  ...        1.30        0.15
#
#      Other_players  Global_players  Critic_Score  Critic_Count  User_Score  \
# 1             0.77           40.24           NaN           NaN         NaN
# 200           0.22            5.07           NaN           NaN         NaN
#
#      User_Count  Developer Rating
# 1           NaN        NaN    NaN
# 200         NaN        NaN    NaN
#
# [2 rows x 23 columns]

# %%
df3.loc[16500]
# Out:
# Rank                                    16571
# Name                              XI Coliseum
# Platform                                  PSP
# Year                                     2006
# Genre                                  Puzzle
# Publisher         Sony Computer Entertainment
# NA_Sales                                    0
# EU_Sales                                    0
# JP_Sales                                 0.01
# Other_Sales                                 0
# Global_Sales                             0.01
# Unnamed: 0                              16684
# NA_players                                  0
# EU_players                                  0
# JP_players                               0.01
# Other_players                               0
# Global_players                           0.01
# Critic_Score                              NaN
# Critic_Count                              NaN
# User_Score                                NaN
# ...

# %%
uniq = df3['Platform'].unique()
uniq
# Out:
# array(['Wii', 'NES', 'GB', 'DS', 'X360', 'PS3', 'PS2', 'SNES', 'GBA',
#        '3DS', 'PS4', 'N64', 'PS', 'XB', 'PC', '2600', 'PSP', 'XOne', 'GC',
#        'WiiU', 'GEN', 'DC', 'PSV', 'SAT', 'SCD', 'WS', 'NG', 'TG16',
#        '3DO', 'GG', 'PCFX'], dtype=object)
